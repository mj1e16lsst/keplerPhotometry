# %%
from astropy.io import ascii
from sqlalchemy import create_engine
import sqlite3
import mysql.connector
import time

# %%
engine = create_engine('mysql://mj1e16:[sqlT1G3R]@localhost/Kepler')
data = ascii.read('/home/mj1e16/iraf/starfield.dat')
conn = mysql.connector.Connect(host='localhost',user='mj1e16',password='[sqlT1G3R]',database='Kepler')
curse = conn.cursor()

# %%
df = data.to_pandas()

# %%
tableName = 'starlist'
df.to_sql(tableName, con=engine)

# %%
0.00178003311157*3000000
# Out:
# 5340.09933471

# %%
t0 =time.time()
conn = mysql.connector.Connect(host='localhost',user='mj1e16',password='[sqlT1G3R]',database='Kepler')
print(time.time()-t0)
print(conn.is_connected())
# Out:
# 0.00178003311157
# True

# %%
cursor = conn.cursor()
cursor.execute("SELECT * FROM starlist")
row = cursor.fetchall()

# %%
print(row)
# Out:
# [(0, 672.635, 21.586, -0.166), (1, 260.868, 21.621, -1.214), (2, 1100.515, 21.678, -0.228), (3, 260.555, 21.924, -0.039), (4, 157.854, 22.024, -0.827), (5, 155.669, 22.146, -0.525), (6, 98.69, 22.468, -0.02), (7, 560.421, 22.666, -0.282), (8, 183.649, 23.631, -0.198), (9, 886.768, 23.716, -0.759), (10, 532.062, 23.841, -1.97), (11, 934.288, 23.934, -2.193), (12, 288.328, 24.157, -0.767), (13, 848.294, 24.198, -1.053), (14, 18.161, 24.316, -1.342), (15, 653.337, 24.423, -1.531), (16, 1033.766, 24.734, -0.694), (17, 926.822, 24.822, -0.719), (18, 358.419, 24.907, -1.679), (19, 346.509, 24.952, -0.06), (20, 804.999, 25.51, -0.518), (21, 919.953, 25.576, -0.488), (22, 439.761, 25.621, -0.363), (23, 603.997, 25.979, -0.376), (24, 708.592, 26.263, -0.062), (25, 353.329, 26.275, -0.04), (26, 647.547, 26.298, -1.087), (27, 414.708, 26.307, -0.11), (28, 967.728, 26.354, -2.434), (29, 995.362, 26.641, -0.397), (30, 705.697, 26.664, -0.796), (31, 483.276, 26.834, -0.036), (32, 1024.188, 26.914, -0.056), (33, 308.288, 27.234, -1.079), (34, 597.691, 27.412, -0.151), (35, 463.371, 27.434, -1.928), (36, 119.942, 27.555, -0.007), (37, 956.785, 27.581, -0.045), (38, 1024.349, 27.99, -0.143), (39, 281.88, 28.098, -1.737), (40, 440.387, 28.314, -0.002), (41, 908.67, 28.314, -0.139), (42, 121.743, 28.371, -0.128), (43, 696.879, 28.547, -1.103), (44, 358.152, 28.576, -0.467), (45, 400.747, 28.842, -1.506), (46, 866.167, 29.674, -0.069), (47, 1038.495, 29.695, -0.104), (48, 740.923, 30.094, -0.116), (49, 61.857, 30.107, -0.205), (50, 1057.296, 30.169, -0.077), (51, 1051.623, 30.488, -0.109), (52, 569.856, 30.497, -1.396), (53, 507.395, 30.669, -0.943), (54, 677.103, 30.949, -0.017), (55, 15.514, 31.057, -0.703), (56, 847.95, 31.32, -0.894), (57, 779.784, 31.466, -0.608), (58, 399.476, 31.49, -0.281), (59, 257.896, 31.736, -2.222), (60, 34.73, 32.01, -0.351), (61, 954.028, 32.072, -0.31), (62, 122.629, 32.188, -2.349), (63, 780.515, 32.545, -0.039), (64, 1097.186, 32.596, -0.12), (65, 1076.716, 32.771, -2.284), (66, 398.021, 32.859, -0.002), (67, 483.004, 33.068, -0.236), (68, 1021.434, 33.295, -0.105), (69, 588.343, 33.333, -0.162), (70, 686.042, 33.434, -0.384), (71, 635.84, 33.434, -2.103), (72, 638.326, 34.021, -0.504), (73, 223.606, 34.165, -0.309), (74, 915.225, 34.208, -0.271), (75, 350.978, 34.232, -0.625), (76, 35.776, 34.844, -0.054), (77, 912.177, 34.917, -1.737), (78, 245.032, 34.944, -2.45), (79, 186.07, 35.063, -0.772), (80, 963.519, 35.091, -0.02), (81, 243.601, 35.275, -0.085), (82, 443.096, 35.291, -0.674), (83, 351.696, 35.42, -0.331), (84, 959.394, 35.667, -0.22), (85, 432.422, 35.812, -0.353), (86, 346.715, 35.992, -0.289), (87, 149.064, 36.377, -0.931), (88, 810.018, 36.48, -1.032), (89, 386.205, 36.589, -0.293), (90, 63.504, 36.672, -1.285), (91, 25.381, 36.944, -0.445), (92, 475.212, 37.415, -0.035), (93, 62.811, 37.576, -0.826), (94, 30.233, 37.784, -0.528), (95, 819.665, 37.867, -0.838), (96, 762.912, 37.896, -0.4), (97, 813.123, 38.208, -0.609), (98, 1076.751, 38.221, -0.499), (99, 736.399, 38.231, -3.222), (100, 764.855, 38.261, -1.372), (101, 55.583, 38.314, -1.351), (102, 325.871, 38.404, -0.3), (103, 625.864, 38.89, -0.431), (104, 583.402, 38.932, -0.951), (105, 256.554, 39.305, -0.312), (106, 896.705, 39.431, -0.637), (107, 1002.134, 39.431, -0.153), (108, 514.881, 39.712, -0.287), (109, 350.995, 40.129, -2.1), (110, 952.365, 40.534, -0.573), (111, 1023.478, 40.871, -0.097), (112, 75.323, 41.093, -0.001), (113, 238.539, 41.697, -2.186), (114, 544.654, 41.7, -0.915), (115, 630.246, 41.835, -0.743), (116, 1109.308, 41.844, -0.466), (117, 571.653, 42.197, -0.468), (118, 242.726, 42.233, -0.195), (119, 664.378, 42.279, -1.402), (120, 516.693, 42.729, -0.509), (121, 392.26, 42.749, -2.504), (122, 110.791, 43.048, -0.158), (123, 1085.35, 43.287, -0.137), (124, 931.971, 43.771, -0.611), (125, 514.258, 44.098, -0.421), (126, 1049.068, 44.129, -1.341), (127, 49.376, 44.983, -0.014), (128, 368.068, 45.076, -0.295), (129, 266.484 ...

# %%
curse.execute("SELECT * FROM starlist")

# %%
conn.info_query("SELECT * FROM starlist LIMIT 1")
# Out:
# (0, 672.635, 21.586, -0.166)

# %%
cursor = conn.cursor(dictionary=True)

# %%
curso

# %%
print(b)
# Out:
# None

# %%
# Out:
# NoneType
