# %%
# %% ----------------------------------------------------------------
# %% AppendixA.tex
# %% ----------------------------------------------------------------
# \chapter{Appendix: Finding Transients Surplus} \label{Chapter:Stuff}
#
# \section{SExtractor Settings}
#
# The full list of SExtractor filters used in the simulations was:
# \begin{itemize}
# \item default.conv
# \item gauss\_1.5\_3x3.conv
# \item gauss\_2.0\_3x3.conv
# \item gauss\_2.0\_5x5.conv
# \item gauss\_2.5\_5x5.conv
# \item gauss\_3.0\_5x5.conv
# \item gauss\_3.0\_7x7.conv
# \item gauss\_4.0\_7x7.conv
# \item gauss\_5.0\_9x9.conv
# \item mexhat\_1.5\_5x5.conv
# \item mexhat\_2.0\_7x7.conv
# \item mexhat\_2.5\_7x7.conv
# \item mexhat\_3.0\_9x9.conv
# \item mexhat\_4.0\_9x9.conv
# \item mexhat\_5.0\_11x11.conv
# \item tophat\_1.5\_3x3.conv
# \item tophat\_2.0\_3x3.conv
# \item tophat\_2.5\_3x3.conv
# \item tophat\_3.0\_3x3.conv
# \item tophat\_4.0\_5x5.conv
# \item tophat\_5.0\_5x5.conv
# \end{itemize}
#
# \section{Completeness and Accuracy for Each Filter} \label{app:compacc}
#
# \begin{figure}\label{fig:default.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{accdefault.conv}.png}
# \caption{The accuracy of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'default.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:gauss_1.5_3x3.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{accgauss_1.5_3x3.conv}.png}
# \caption{The accuracy of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'gauss\_1.5\_3x3.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:gauss_2.0_3x3.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{accgauss_2.0_3x3.conv}.png}
# \caption{The accuracy of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'gauss\_2.0\_3x3.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:gauss_2.0_5x5.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{accgauss_2.0_5x5.conv}.png}
# \caption{The accuracy of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'gauss\_2.0\_5x5.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:gauss_2.5_5x5.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{accgauss_2.5_5x5.conv}.png}
# \caption{The accuracy of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'gauss\_2.5\_5x5.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:gauss_3.0_5x5.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{accgauss_3.0_5x5.conv}.png}
# \caption{The accuracy of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'gauss\_3.0\_5x5.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:gauss_3.0_7x7.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{accgauss_3.0_7x7.conv}.png}
# \caption{The accuracy of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'gauss\_3.0\_7x7.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:gauss_4.0_7x7.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{accgauss_4.0_7x7.conv}.png}
# \caption{The accuracy of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'gauss\_4.0\_7x7.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:gauss_5.0_9x9.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{accgauss_5.0_9x9.conv}.png}
# \caption{The accuracy of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'gauss\_5.0\_9x9.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:mexhat_1.5_5x5.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{accmexhat_1.5_5x5.conv}.png}
# \caption{The accuracy of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'mexhat\_1.5\_5x5.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:mexhat_2.0_7x7.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{accmexhat_2.0_7x7.conv}.png}
# \caption{The accuracy of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'mexhat\_2.0\_7x7.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:mexhat_2.5_7x7.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{accmexhat_2.5_7x7.conv}.png}
# \caption{The accuracy of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'mexhat\_2.5\_7x7.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:mexhat_3.0_9x9.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{accmexhat_3.0_9x9.conv}.png}
# \caption{The accuracy of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'mexhat\_3.0\_9x9.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:mexhat_4.0_9x9.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{accmexhat_4.0_9x9.conv}.png}
# \caption{The accuracy of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'mexhat\_4.0\_9x9.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:mexhat_5.0_11x11.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{accmexhat_5.0_11x11.conv}.png}
# \caption{The accuracy of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'mexhat\_5.0\_11x11.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:tophat_1.5_3x3.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{acctophat_1.5_3x3.conv}.png}
# \caption{The accuracy of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'tophat\_1.5\_3x3.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:tophat_2.0_3x3.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{acctophat_2.0_3x3.conv}.png}
# \caption{The accuracy of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'tophat\_2.0\_3x3.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:tophat_2.5_3x3.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{acctophat_2.5_3x3.conv}.png}
# \caption{The accuracy of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'tophat\_2.5\_3x3.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:tophat_3.0_3x3.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{acctophat_3.0_3x3.conv}.png}
# \caption{The accuracy of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'tophat\_3.0\_3x3.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
# \end{figure}
# \begin{figure}\label{fig:tophat_4.0_5x5.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{acctophat_4.0_5x5.conv}.png}
# \caption{The accuracy of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'tophat\_4.0\_5x5.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
# \end{figure}
#
# \begin{figure}\label{fig:tophat_5.0_5x5.conv}
#
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{acctophat_5.0_5x5.conv}.png}
# \caption{The accuracy of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'tophat\_5.0\_5x5.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#
# \begin{figure}\label{fig:default.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{compdefault.conv}.png}
# \caption{The completeness of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'default.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:gauss_1.5_3x3.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{compgauss_1.5_3x3.conv}.png}
# \caption{The completeness of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'gauss\_1.5\_3x3.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:gauss_2.0_3x3.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{compgauss_2.0_3x3.conv}.png}
# \caption{The completeness of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'gauss\_2.0\_3x3.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:gauss_2.0_5x5.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{compgauss_2.0_5x5.conv}.png}
# \caption{The completeness of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'gauss\_2.0\_5x5.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:gauss_2.5_5x5.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{compgauss_2.5_5x5.conv}.png}
# \caption{The completeness of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'gauss\_2.5\_5x5.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:gauss_3.0_5x5.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{compgauss_3.0_5x5.conv}.png}
# \caption{The completeness of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'gauss\_3.0\_5x5.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:gauss_3.0_7x7.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{compgauss_3.0_7x7.conv}.png}
# \caption{The completeness of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'gauss\_3.0\_7x7.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:gauss_4.0_7x7.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{compgauss_4.0_7x7.conv}.png}
# \caption{The completeness of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'gauss\_4.0\_7x7.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:gauss_5.0_9x9.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{compgauss_5.0_9x9.conv}.png}
# \caption{The completeness of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'gauss\_5.0\_9x9.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:mexhat_1.5_5x5.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{compmexhat_1.5_5x5.conv}.png}
# \caption{The completeness of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'mexhat\_1.5\_5x5.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:mexhat_2.0_7x7.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{compmexhat_2.0_7x7.conv}.png}
# \caption{The completeness of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'mexhat\_2.0\_7x7.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:mexhat_2.5_7x7.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{compmexhat_2.5_7x7.conv}.png}
# \caption{The completeness of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'mexhat\_2.5\_7x7.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:mexhat_3.0_9x9.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{compmexhat_3.0_9x9.conv}.png}
# \caption{The completeness of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'mexhat\_3.0\_9x9.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:mexhat_4.0_9x9.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{compmexhat_4.0_9x9.conv}.png}
# \caption{The completeness of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'mexhat\_4.0\_9x9.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:mexhat_5.0_11x11.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{compmexhat_5.0_11x11.conv}.png}
# \caption{The completeness of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'mexhat\_5.0\_11x11.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:tophat_1.5_3x3.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{comptophat_1.5_3x3.conv}.png}
# \caption{The completeness of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'tophat\_1.5\_3x3.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:tophat_2.0_3x3.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{comptophat_2.0_3x3.conv}.png}
# \caption{The completeness of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'tophat\_2.0\_3x3.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:tophat_2.5_3x3.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{comptophat_2.5_3x3.conv}.png}
# \caption{The completeness of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'tophat\_2.5\_3x3.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:tophat_3.0_3x3.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{comptophat_3.0_3x3.conv}.png}
# \caption{The completeness of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'tophat\_3.0\_3x3.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:tophat_4.0_5x5.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{comptophat_4.0_5x5.conv}.png}
# \caption{The completeness of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'tophat\_4.0\_5x5.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
#   \begin{figure}\label{fig:tophat_5.0_5x5.conv}
# % To include a figure from a file named example.*
# % Allowable file formats are eps or ps if compiling using latex
# % or pdf, png, jpg if compiling using pdflatex
# \includegraphics[width=0.7\columnwidth]{{comptophat_5.0_5x5.conv}.png}
# \caption{The completeness of the detection workflow when using different combinations of detection threshold and minimum area for the filter 'tophat\_5.0\_5x5.conv'. The accuracy quality metric was averaged over the spatial distribution, magnitude range and all three CCD channels used.}
#
#   \end{figure}
