# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

import astropy
from astropy.coordinates import SkyCoord
from astropy import units as u

from astroquery.vizier import Vizier
from scipy import ndimage
import scipy.misc
from astropy.table import Table
from astropy.io import ascii

# %%
tranObjects = ascii.read('/home/mj1e16/outTablesImproved/fullMatches.csv')
ra = tranObjects['RA']
dec = tranObjects['DEC']

# %%
sne = ascii.read('/home/mj1e16/outTablesImproved/supernovae.csv')
snera = sne['RA']
snedec = sne['DEC']

# %%
ra
# Out:
# <MaskedColumn name='RA' dtype='float64' length=36>
#  291.9081476036849
#  282.2997286819453
# 286.17639521590405
# 282.51787304188844
# 286.16801092086166
#  284.7198297858132
#   294.896920769719
#  283.1588141524291
# 282.85892686984414
#  291.2033637056251
# 285.98714822273195
# 283.06651744945054
#                ...
#   290.814807618147
# 281.94363497010085
#  282.7021468847232
# 282.16748804574934
#  280.4266698423564
#   281.243090037762
# 283.43281807912626
#  297.5177467782924
#   284.143641438747
#  284.7595454401471
#  282.8932701888228
#  291.5945226643946

# %%
img=mpimg.imread('/home/mj1e16/Pictures/other/kplrffi.png')
fig,ax = plt.subplots(figsize=(10,10))
#plt.plot([0,5,10],[0,5,10])
imgplot = plt.imshow(img, interpolation="bicubic",extent=[302.45,279,36,53])
plt.plot(ra,dec,'ko')
plt.plot(snera,snedec,'bo')
for x in range(len(ra)):
    plt.annotate('{},{}'.format(ra[x],dec[x]),xy=(ra[x],dec[x]))
plt.show()

# %%
c1 = SkyCoord(ra=281*u.deg,dec=48*u.deg,frame='fk5')
c2 = SkyCoord(ra=286*u.deg,dec=38*u.deg)
c3 = SkyCoord(ra=283*u.deg,dec=44*u.deg)
c4 = SkyCoord(ra=297*u.deg,dec=51*u.deg)
c5 = SkyCoord(ra=280*u.deg,dec=41*u.deg)
c6 = SkyCoord(ra=290*u.deg,dec=52*u.deg)

# %%
print(c1.galactic)
print(c2.galactic)
print(c3.galactic)
print(c4.galactic)
print(c5.galactic)
print(c6.galactic)
# Out:
# <SkyCoord (Galactic): (l, b) in deg
#     (77.18168541, 20.98880899)>
# <SkyCoord (Galactic): (l, b) in deg
#     (68.73858209, 14.02290895)>
# <SkyCoord (Galactic): (l, b) in deg
#     (73.6463039, 18.37185128)>
# <SkyCoord (Galactic): (l, b) in deg
#     (84.23326916, 12.56435575)>
# <SkyCoord (Galactic): (l, b) in deg
#     (69.86936208, 19.43032148)>
# <SkyCoord (Galactic): (l, b) in deg
#     (83.24721258, 16.93044018)>

# %%
img=mpimg.imread('/home/mj1e16/Pictures/other/kplrfficroper.png')
fig,ax = plt.subplots(figsize=(10,10))
#plt.plot([0,5,10],[0,5,10])
imgplot = plt.imshow(img, interpolation="bicubic",extent=[302.45,279,36,53])
plt.plot(ra,dec,'ko')
# plt.xlim([302.5,279])
# plt.ylim([36.5,53])
plt.show()

# %%
for degree in range(5):
    img=mpimg.imread('/home/mj1e16/Pictures/kplrffi.png')
    rotated_img = ndimage.rotate(img, degree*90)

    raDeg = []
    decDeg = []


    for x in range(len(ra)):
        c = SkyCoord(ra[x]+' '+dec[x], unit=(u.hourangle, u.deg))
        raDeg.append(c.ra.degree)
        decDeg.append(c.dec.degree)


    print(raDeg,decDeg)
    fig,ax = plt.subplots(figsize=(10,10))
    #plt.plot([0,5,10],[0,5,10])
    imgplot = plt.imshow(rotated_img, interpolation="bicubic",extent=[302.45,279,36,53])
    ax.plot(raDeg,decDeg,'ko')
    plt.xlim(302.45,279)
    plt.ylim(36,53)
    for x in range(len(name)):
        ax.annotate(name[x],xy=(raDeg[x],decDeg[x]))
    plt.show()
# Out:
# ([293.3754458333333, 290.15641666666664, 291.1920374999999], [45.25035833333333, 38.252316666666665, 43.68074444444444])
# ([293.3754458333333, 290.15641666666664, 291.1920374999999], [45.25035833333333, 38.252316666666665, 43.68074444444444])
# ([293.3754458333333, 290.15641666666664, 291.1920374999999], [45.25035833333333, 38.252316666666665, 43.68074444444444])
# ([293.3754458333333, 290.15641666666664, 291.1920374999999], [45.25035833333333, 38.252316666666665, 43.68074444444444])
# ([293.3754458333333, 290.15641666666664, 291.1920374999999], [45.25035833333333, 38.252316666666665, 43.68074444444444])

# %%
print(img.shape,type(img))
# Out:
# ((500, 457, 3), <type 'numpy.ndarray'>)

# %%
img=mpimg.imread('/home/mj1e16/Pictures/kplrffi.png')
fig,ax = plt.subplots(figsize=(10,10))
#plt.plot([0,5,10],[0,5,10])
imgplot = plt.imshow(img, interpolation="bicubic",extent=[302.45,279,36,53])
plt.plot(ra,dec,'ko')
plt.xlim(302.45,279)
plt.ylim(36,53)
plt.show()

# %%
img=mpimg.imread('kplrffi.png')
fig,ax = plt.subplots(figsize=(10,10))
#plt.plot([0,5,10],[0,5,10])
imgplot = plt.imshow(img, interpolation="bicubic",extent=[302.45,279,36,53])
plt.plot(ra,dec,'ko')
plt.show()

# %%
img=mpimg.imread('kplrffi.png')
fig,ax = plt.subplots(figsize=(10,10))
#plt.plot([0,5,10],[0,5,10])
imgplot = plt.imshow(img, interpolation="bicubic",extent=[302.45,279,36,53])
plt.plot(ra,dec,'ko')
plt.xlim(302.45,279)
plt.ylim(36,53)
plt.show()

# %%
# img=mpimg.imread('kplrffi.png')
# fig,ax = plt.subplots(figsize=(10,10))
# #plt.plot([0,5,10],[0,5,10])
# imgplot = plt.imshow(img, interpolation="bicubic",extent=[302.45,279,36,53])
# plt.plot(ra,dec,'ko')
# plt.xlim(302.45,279)
# plt.ylim(35,55)
# plt.show()

# %%
img=mpimg.imread('kplrffi.png')
fig,ax = plt.subplots(figsize=(10,10))
#plt.plot([0,5,10],[0,5,10])
imgplot = plt.imshow(img, interpolation="bicubic",extent=[302.45,279,36,53])
plt.plot(ra,dec,'ko')
plt.show()

# %%
img=mpimg.imread('kplrffi.png')
fig,ax = plt.subplots(figsize=(10,10))
#plt.plot([0,5,10],[0,5,10])
imgplot = plt.imshow(img, interpolation="bicubic",extent=[302.45,279,36,53])
plt.plot(raDeg,decDeg,'ko')
plt.show()

# %%
img=mpimg.imread('kplrffi.png')
fig,ax = plt.subplots(figsize=(10,10))
#plt.plot([0,5,10],[0,5,10])
imgplot = plt.imshow(img, interpolation="bicubic",extent=[302.45,279,36,53])
plt.plot(raDeg,decDeg,'ko')
plt.xlim(302.45,279)
plt.ylim(36,53)
plt.show()

# %%
img=mpimg.imread('kplrffi.png')
fig,ax = plt.subplots(figsize=(10,10),projection="mollweide")
#plt.plot([0,5,10],[0,5,10])
imgplot = plt.imshow(img, interpolation="bicubic",extent=[302.45,279,36,53])
plt.plot(raDeg,decDeg,'ko')
plt.show()
